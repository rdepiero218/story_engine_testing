# %% [markdown]
# # Construct CSV for upload to story engine web app

# %%
import pandas as pd

pd.set_option('max_colwidth', 100)

# %%
### for testing
df = pd.read_csv(f'../data/politics_cards.csv')

# %%
df['engine'].dropna()
# Out:
# 0             Wants to become the dominant party with
# 1              Wants to tip the balance of power with
# 2             Wants to stop a destructive agenda with
# 3                   Wants to blow the whistle on/with
# 4                           Wants to escape from/with
# 5                Wants to root out corruption with/on
# 6                           Wants to bribe with/about
# 7     Wants to relinquish control of their party with
# 8          Wants to restore the balance of power with
# 9             Wants to push an aggressive agenda with
# 10               Wants to protect a policy about/with
# 11                    Wants to expose a coverup about
# 12                      Wants to pass an bill on/with
# 13                         Is being bribed with/about
# Name: engine, dtype: object

# %%
df.columns

# %%
df.columns.to_list()

# %%
col_list = df['agent'].to_list()

df['agent']
# Out:
# 0              Governor
# 1                 Mayor
# 2               Insider
# 3               Analyst
# 4          Propagandist
# 5     Company Spokesman
# 6       Black Ops Agent
# 7                 Fixer
# 8                 Judge
# 9               Warlord
# 10              Senator
# 11            Selectman
# 12        Whistleblower
# 13              Handler
# 14             Lobbyist
# 15        PR Consultant
# Name: agent, dtype: object

# %%
len(col_list)
# Out:
# 16

# %%
lines = []
line = col_list[0:4]

# for i in range(0,len(col_list)):
#     lines[
line2 = str.join(';',line)
line3 = str.join(';;', line2[-1])

# %%
line2

# %%
line3

# %%
line3 = line2+';;'
line3

# %%
types = df.columns.to_list()
types

# %%
# for feature in types:
features = df.columns.to_list()

feature = features[0]
col_list = df[feature].to_list()
start = 0
end = 4
new_col = []
for i in range(0,len(col_list)//4):
    chunk = col_list[start:end]
    line = str.join(';',chunk)
    line = feature + ';' +  line + ';;'
    new_col.append(line)
    start = end
    end = end + 4
        
new_col

# %%
# for feature in types:
features = df.columns.to_list()

new_df = pd.DataFrame()

two_sided = ['engine', 'conflict']

new_col = []
for feature in features:
    col_list = df[feature].dropna().to_list()
    # print(feature)

    # print(feature)
    # print(col_list)
    if feature in two_sided:
        # print('the feature is: %s'%(feature))
        start = 0
        finish = 2
        for i in range(0,len(col_list)//2):
            chunk = col_list[start:finish]
            line = str.join(';', chunk)
            line = feature + ';' +  line + ';;'
            new_col.append(line)
            start = finish
            finish += 2
    else:
        start = 0
        finish = 4
        for i in range(0,len(col_list)//4):
            chunk = col_list[start:finish]
            line = str.join(';', chunk)
            line = feature + ';' +  line + ';;'
            new_col.append(line)
            start = finish
            finish += 4
            # print('feature: %s start: %d finish %d i: %i'%(feature, start, finish, i))
    new_df = pd.DataFrame(new_col)

# new_df = pd.concat(new_df, s)

# %%
new_df
# Out:
#                                                                                                       0
# 0                                                  aspect;Government-Funded;Deputized;Partisan;Rigged;;
# 1                                             aspect;Poorly Funded;Researched;Highly political;Buried;;
# 2                                           aspect; State-Funded; Commissioned;Apolitical;Compromised;;
# 3                                                     aspect;Well-Funded;Hired;Non-partisan;Tarnished;;
# 4                                                                agent;Governor;Mayor;Insider;Analyst;;
# 5                                          agent;Propagandist;Company Spokesman;Black Ops Agent;Fixer;;
# 6                                                               agent;Judge;Warlord;Senator;Selectman;;
# 7                                                  agent;Whistleblower;Handler;Lobbyist;PR Consultant;;
# 8               engine;Wants to become the dominant party with;Wants to tip the balance of power with;;
# 9                    engine;Wants to stop a destructive agenda with;Wants to blow the whistle on/with;;
# 10                              engine;Wants to escape from/with;Wants to root out corruption with/on;;
# 11                   engine;Wants to bribe with/about;Wants to relinquish control of their party with;;
# 12          engine;Wants to restore the balance of power with;Wants to push an aggressive agenda with;;
# 13                       engine; Wants to protect a policy about/with;Wants to expose a coverup about;;
# 14                                    engine;Wants to pass an bill on/with;Is being bribed with/about;;
# 15                                             anchor;Washington DC;Big City;A rival nation;A dossier;;
# 16                    anchor;A top secret program;A CIA black site;An innocent bystander;Capitol Hill;;
# 17                          anchor;Small Town;An allied nation;A list of names;A Senate investigation;;
# 18                                anchor;A secret prison;A puppet master;The White House;Rural Region;;
# 19                 conflict;But it will cost them the election;But history will see them as a villain;;
# 20             conflict;But it will end their career;But it will undermine their own political agenda;;
# 21  conflict;But they will discover a horrifying truth about their allies;But bureaucracy will hold ...
# 22    conflict;But they will fail someone relying on them;But the opposing party will come into power;;
# 23       conflict;But history will see them as a failure;But it will end the career of a trusted ally;;
# 24  conflict;But it will destroy their belief in their own political party;But they will prove their...
# 25   conflict;But the system will treat them unjustly;But they will make a steep political compromise;;

# %%
pol = pd.read_csv(f'../data/politics.csv')
pol
# Out:
#                                                          agent;Governor;Senator;President;Congressman;;
# 0                                                              agent;Mayor;Selectman;Alderman;Sheriff;;
# 1                                                      agent;Insider;Whistleblower;Informant;Reporter;;
# 2                                                    agent;Analyst;Handler;Researcher;Department Head;;
# 3                                            agent;Propagandist;Lobbyist;Union Leader;Industry Leader;;
# 4                                      agent;Company Spokesman;PR Consultant;Aid;Head of a Non-profit;;
# 5                                            agent;Black Ops Agent;FBI Agent;CIA Agent;Police Officer;;
# 6                                                 agent;Fixer;Military Contractor;Dealmaker;Regulator;;
# 7                                                       agent;Judge;Lawyer;Public Defender;Prosecutor;;
# 8                                                            agent;Warlord;Arms Dealer;Veteran;Victim;;
# 9      engine;Wants to become the dominant party with;Wants to relinquish control of their party with;;
# 10           engine;Wants to tip the balance of power with;Wants to restore the balance of power with;;
# 11             engine;Wants to stop a destructive agenda with;Wants to push an aggressive agenda with;;
# 12                     engine;Wants to blow the whistle on/with; Wants to protect a policy about/with;;
# 13                                   engine;Wants to escape from/with;Wants to expose a coverup about;;
# 14                          engine;Wants to root out corruption with/on;Wants to pass an bill on/with;;
# 15                                        engine;Wants to bribe with/about;Is being bribed with/about;;
# 16                                     anchor;Washington DC;Capitol Hill;The White House;The Pentagon;;
# 17                                          anchor;Big City;Small Town;Rural Region;Key Shipping Port;;
# 18                             anchor;A rival nation;An allied nation;An allied leader;A rival leader;;
# 19                                 anchor;A dossier;A list of names;Key information;A terrible secret;;
# 20                     anchor;A top secret program;A Senate investigation;A vaccine trial;An election;;
# 21                                 anchor;A CIA black site;A secret prison;An embassy;A military base;;
# 22                         anchor;An innocent bystander;A puppet master;A polititian;A reckless agent;;
# 23            conflict;But it will cost them the election;But the opposing party will come into power;;
# 24             conflict;But history will see them as a villain;But history will see them as a failure;;
# 25                 conflict;But it will end their career;But it will end the career of a trusted ally;;
# 26  conflict;But it will undermine their own political agenda;But it will destroy their belief in th...
# 27  conflict;But they will discover a horrifying truth about their allies;But they will prove their ...
# 28                conflict;But bureaucracy will hold them back;But the system will treat them unjustly;
# 29  conflict;But they will fail someone relying on them;But they will make a steep political comprom...
# 30                                   aspect;Government-Funded;Poorly Funded; State-Funded;Well-Funded;;
# 31                                                    aspect;Deputized;Researched; Commissioned;Hired;;
# 32                                           aspect;Partisan;Highly political;Apolitical;Non-partisan;;
# 33                                                         aspect;Rigged;Buried;Compromised;Tarnished;;

# %%
df2 = pd.concat([pd.Series(new_col), pd.Series(new_col)])

# %%
df2
